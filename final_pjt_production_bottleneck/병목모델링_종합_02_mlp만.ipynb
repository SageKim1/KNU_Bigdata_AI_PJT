# %% [markdown]
# # 파일 불러오기
# - 날짜 없는 원본 파일 사용

# %%
import pandas as pd

# Load the CSV file
file_path = "./Final Results Extended.csv"
df = pd.read_csv(file_path)
df.head()
# Out:
#    Time_Now  Blanking_Util  Blanking_SKU1_Queue  Blanking_SKU2_Queue  \
# 0        24       0.846367             0.045715             0.056373
# 1        24       0.851097             0.051937             0.052934
# 2        24       0.846115             0.052210             0.047499
# 3        24       0.841306             0.051769             0.035436
# 4        24       0.859599             0.045874             0.046802
#
#    Blanking_SKU3_Queue  Blanking_SKU4_Queue  Press1_Util  Press2_Util  \
# 0             0.055737             0.035849     0.410297     0.434561
# 1             0.038512             0.042248     0.455471     0.454445
# 2             0.043181             0.040979     0.496717     0.450816
# 3             0.046788             0.052362     0.433749     0.363004
# 4             0.044507             0.057210     0.418329     0.396826
#
#    Press3_Util  Press4_Util  ...  SKU3_NVA_Time  SKU3_Transport_Time  \
# 0     0.481388     0.399992  ...            0.0             0.537617
# 1     0.387975     0.442986  ...            0.0             0.536764
# 2     0.417308     0.352829  ...            0.0             0.535925
# 3     0.443909     0.456036  ...            0.0             0.535232
# 4     0.499273     0.472454  ...            0.0             0.538142
#
#    SKU3_Wait_Time  SKU3_Other_Time  SKU4_VA_Time  SKU4_NVA_Time  \
# 0        0.453650              0.0      1.523338            0.0
# 1        0.473677              0.0      1.523344            0.0
# 2        0.424090              0.0      1.523403            0.0
# 3        0.430992              0.0      1.523381            0.0
# 4        0.502614              0.0      1.523363            0.0
#
#    SKU4_Transport_Time  SKU4_Wait_Time  SKU4_Other_Time  Blanking_Queue
# 0             0.536243        0.473453              0.0       58.361452
# 1             0.534992        0.464380              0.0       62.830599
# 2             0.535077        0.475330              0.0       59.365867
# 3             0.533233        0.463801              0.0       56.698528
# 4             0.537223        0.449320              0.0       65.784631
#
# [5 rows x 78 columns]

# %% [markdown]
# # 데이터 전처리

# %% [markdown]
# ## 상수컬럼 및 전부 0인 컬럼 제거
# - Time_Now에 동일한 24 값 -> 제거
# - 결과적으로 22개 컬럼 제거
# - Queue 변수 중 제거된 거 : 'Paint1_Queue', 'Paint2_Queue', 'Cell1_Queue', 'Cell2_Queue', 'Cell3_Queue', 'Cell4_Queue'
# - Cell별 SKU 생산량 변수 중 제거된 거 : 'c_Cell1_SKU3', 'c_Cell2_SKU1', 'c_Cell2_SKU3', 'c_Cell3_SKU1', 'c_Cell3_SKU4', 'c_Cell4_SKU1', 'c_Cell4_SKU2'

# %%
# =========================
# 1. 상수컬럼 및 전부 0인 컬럼 제거
# =========================

# (1) 상수컬럼: 데이터가 모두 같은 값인 컬럼
const_cols = [col for col in df.columns if df[col].nunique() == 1]

# (2) 전부 0인 컬럼
zero_cols = [col for col in df.columns if (df[col] == 0).all()]

# 합치기 (중복 제거)
drop_cols = list(set(const_cols + zero_cols))

print(f"🗑 제거 대상 컬럼 수: {len(drop_cols)}개")
print(drop_cols)

# 실제 제거
df = df.drop(columns=drop_cols)

print(f"✅ 제거 후 컬럼 수: {df.shape[1]}")
# Out:
# 🗑 제거 대상 컬럼 수: 22개
# ['c_Cell3__SKU1', 'SKU2_Other_Time', 'Cell1_Queue', 'SKU4_Other_Time', 'Cell2_Queue', 'c_Cell4__SKU1', 'c_Cell2__SKU1', 'SKU1_NVA_Time', 'c_Cell3__SKU4', 'SKU3_NVA_Time', 'c_Cell4__SKU2', 'c_Cell1__SKU3', 'Paint1_Queue', 'SKU2_NVA_Time', 'Cell4_Queue', 'SKU3_Other_Time', 'Paint2_Queue', 'SKU1_Other_Time', 'c_Cell2__SKU3', 'SKU4_NVA_Time', 'Cell3_Queue', 'Time_Now']
# ✅ 제거 후 컬럼 수: 56

# %% [markdown]
# ## 결측치 확인 -> 1~3개씩 존재 => 해당 행 drop (행 3개 제거)

# %%
# =========================
# 2. 결측치 확인
# =========================
missing_summary = df.isnull().sum()
missing_summary = missing_summary[missing_summary > 0]

if missing_summary.empty:
    print("✅ 결측치 없음")
else:
    print("⚠️ 결측치 요약:")
    print(missing_summary)
# Out:
# ⚠️ 결측치 요약:
# Blanking_SKU4_Queue        1
# Press1_Util                1
# Press2_Util                1
# Press3_Util                1
# Press4_Util                1
# Press1_Queue               1
# Press2_Queue               1
# Press3_Queue               1
# Press4_Queue               1
# Cell1_Util                 1
# Cell2_Util                 1
# Cell3_Util                 1
# Cell4_Util                 1
# Warehouse1_Queue           1
# Warehouse_2_Queue          1
# Warehouse_3_Queue          1
# Warehouse_4_Queue          1
# c_Cycle1                   1
# c_Cycle2                   1
# c_Cycle3                   1
# c_Cycle4                   1
# c_Cell1_SKU1               1
# c_Cell1__SKU2              1
# c_Cell1__SKU4              1
# c_Cell2__SKU2              1
# c_Cell2__SKU4              1
# c_Cell3__SKU2              1
# c_Cell3__SKU3              1
# c_Cell4__SKU3              1
# c_Cell4__SKU4              1
# Paint1_Util                1
# Paint2_Util                1
# Quality_Util               1
# Quality_Queue              1
# Forklift_Util              1
# Forklift_Blanking_Queue    1
# Forklift_Press_Queue       1
# Forklift_Assembly_Queue    1
# c_TotalProducts            1
# SKU1_VA_Time               1
# SKU1_Transport_Time        2
# SKU1_Wait_Time             3
# SKU2_VA_Time               3
# SKU2_Transport_Time        3
# SKU2_Wait_Time             3
# SKU3_VA_Time               3
# SKU3_Transport_Time        3
# SKU3_Wait_Time             3
# SKU4_VA_Time               3
# SKU4_Transport_Time        3
# SKU4_Wait_Time             3
# Blanking_Queue             3
# dtype: int64

# %%
# =========================
# 3. 결측치 제거
# =========================
if not missing_summary.empty:
    before = df.shape[0]
    df = df.dropna()  # 결측치가 하나라도 있는 행 제거
    after = df.shape[0]
    print(f"✅ 결측치가 있는 행 {before - after}개 제거 완료 (남은 행: {after})")

print()
missing_summary2 = df.isnull().sum()
missing_summary2 = missing_summary2[missing_summary2 > 0]
print(missing_summary2)
# Out:
# ✅ 결측치가 있는 행 3개 제거 완료 (남은 행: 132673)
#
# Series([], dtype: int64)

# %% [markdown]
# # Warehouse Queue -> 네이밍을 Cell Queue 로 변경 (with 넘버링 매핑)
# - 이름 변경 매핑: {'Warehouse1_Queue': 'Cell1_Queue', 'Warehouse_2_Queue': 'Cell2_Queue', 'Warehouse_3_Queue': 'Cell3_Queue', 'Warehouse_4_Queue': 'Cell4_Queue'}

# %%
# =========================
# 1) Warehouse Queue 컬럼 찾기
# =========================
warehouse_cols = [c for c in df.columns if "warehouse" in c.lower() and "queue" in c.lower()]
print("Warehouse Queue cols:", warehouse_cols)

# =========================
# 2) Warehouse 번호 → Cell 번호로 변환
# =========================
rename_map = {}
for w in warehouse_cols:
    # 숫자 추출 (예: Warehouse1_Queue → 1)
    num = ''.join(filter(str.isdigit, w))
    if num:
        new_name = f"Cell{num}_Queue"
        rename_map[w] = new_name

# =========================
# 3) 컬럼명 변경
# =========================
df = df.rename(columns=rename_map)

print("✅ 이름 변경 매핑:", rename_map)
print("변경 후 Queue 관련 컬럼:", [c for c in df.columns if "queue" in c.lower()])
# Out:
# Warehouse Queue cols: ['Warehouse1_Queue', 'Warehouse_2_Queue', 'Warehouse_3_Queue', 'Warehouse_4_Queue']
# ✅ 이름 변경 매핑: {'Warehouse1_Queue': 'Cell1_Queue', 'Warehouse_2_Queue': 'Cell2_Queue', 'Warehouse_3_Queue': 'Cell3_Queue', 'Warehouse_4_Queue': 'Cell4_Queue'}
# 변경 후 Queue 관련 컬럼: ['Blanking_SKU1_Queue', 'Blanking_SKU2_Queue', 'Blanking_SKU3_Queue', 'Blanking_SKU4_Queue', 'Press1_Queue', 'Press2_Queue', 'Press3_Queue', 'Press4_Queue', 'Cell1_Queue', 'Cell2_Queue', 'Cell3_Queue', 'Cell4_Queue', 'Quality_Queue', 'Forklift_Blanking_Queue', 'Forklift_Press_Queue', 'Forklift_Assembly_Queue', 'Blanking_Queue']

# %% [markdown]
# # Target 컬럼 생성

# %% [markdown]
# ## 전체 기준 병목 파악 -> 새 컬럼에 추가 (Bottleneck_actual , Bottleneck_actual_val)

# %%
# =========================
# 1) Queue 컬럼 찾기 (대소문자 무시)
# =========================
queue_cols = [col for col in df.columns if "queue" in col.lower()]

print(f"Queue 관련 컬럼 수: {len(queue_cols)}")
print(queue_cols[:10])  # 앞 10개만 확인

# =========================
# 2) 병목 공정 컬럼 생성
# =========================
# 각 행에서 queue 값이 가장 큰 컬럼명
df["Bottleneck_actual"] = df[queue_cols].idxmax(axis=1)

# 해당 queue의 실제 최대값도 같이 기록하고 싶다면
df["Bottleneck_val"] = df[queue_cols].max(axis=1)

# =========================
# 3) 결과 확인
# =========================
print(df[["Bottleneck_actual", "Bottleneck_val"]].tail())
# Out:
# Queue 관련 컬럼 수: 17
# ['Blanking_SKU1_Queue', 'Blanking_SKU2_Queue', 'Blanking_SKU3_Queue', 'Blanking_SKU4_Queue', 'Press1_Queue', 'Press2_Queue', 'Press3_Queue', 'Press4_Queue', 'Cell1_Queue', 'Cell2_Queue']
#               Bottleneck_actual  Bottleneck_val
# 132670  Forklift_Blanking_Queue      153.012984
# 132671              Cell1_Queue      185.031493
# 132672              Cell1_Queue      302.349198
# 132673              Cell1_Queue      295.667368
# 132674              Cell1_Queue      166.628981

# %%
# Bottleneck 컬럼의 빈도 계산
bottleneck_counts = df["Bottleneck_actual"].value_counts().head(10)

bottleneck_counts
# Out:
# Bottleneck_actual
# Cell1_Queue                77629
# Forklift_Blanking_Queue    53681
# Cell3_Queue                 1307
# Cell4_Queue                   36
# Forklift_Press_Queue           9
# Press4_Queue                   6
# Press2_Queue                   5
# Name: count, dtype: int64

# %% [markdown]
# ## 주요 공정 단계(블랭킹, 프레스, 조립셀) 기준 병목 파악 -> 새 컬럼에 추가
# - Bottleneck_actual_Blanking , Bottleneck_actual_Press , Bottleneck_actual_Cell
# - Bottleneck_val_Blanking , Bottleneck_val_Press , Bottleneck_val_Cell

# %%
# ================================
# 11. 공정별 실제 병목 레이블 & 값 생성
# ================================
stage_groups = {
    "Blanking": ["Blanking_SKU1_Queue", "Blanking_SKU2_Queue",
                 "Blanking_SKU3_Queue", "Blanking_SKU4_Queue"],
    "Press":    ["Press1_Queue", "Press2_Queue", "Press3_Queue", "Press4_Queue"],
    "Cell":     ["Cell1_Queue", "Cell2_Queue", "Cell3_Queue", "Cell4_Queue"]
}

for stage, cols in stage_groups.items():
    # 병목 컬럼명 (어느 라인/설비가 병목인지)
    df[f"Bottleneck_actual_{stage}"] = df[cols].idxmax(axis=1)
    # 병목 값 (queue 크기)
    df[f"Bottleneck_val_{stage}"] = df[cols].max(axis=1)

# ================================
# 12. 결과 확인
# ================================
check_cols = [c for c in df.columns if c.startswith("Bottleneck_")]
print(df[check_cols].head())
# Out:
#          Bottleneck_actual  Bottleneck_val Bottleneck_actual_Blanking  \
# 0  Forklift_Blanking_Queue      157.256741        Blanking_SKU2_Queue
# 1  Forklift_Blanking_Queue      166.488725        Blanking_SKU2_Queue
# 2              Cell1_Queue      335.401556        Blanking_SKU1_Queue
# 3  Forklift_Blanking_Queue      147.448407        Blanking_SKU4_Queue
# 4  Forklift_Blanking_Queue      150.397600        Blanking_SKU4_Queue
#
#    Bottleneck_val_Blanking Bottleneck_actual_Press  Bottleneck_val_Press  \
# 0                 0.056373            Press2_Queue             65.273786
# 1                 0.052934            Press1_Queue             74.772823
# 2                 0.052210            Press2_Queue             72.901066
# 3                 0.052362            Press1_Queue             65.091192
# 4                 0.057210            Press1_Queue             65.075312
#
#   Bottleneck_actual_Cell  Bottleneck_val_Cell
# 0            Cell1_Queue            98.155568
# 1            Cell1_Queue           162.632374
# 2            Cell1_Queue           335.401556
# 3            Cell1_Queue           112.173074
# 4            Cell1_Queue           107.982827

# %% [markdown]
# ## 제품군(SKU) 기준 병목 파악 -> 새 컬럼에 추가
# - Bottleneck_actual_SKU1 , Bottleneck_actual_SKU2 , Bottleneck_actual_SKU3 , Bottleneck_actual_SKU4
# - Bottleneck_val_SKU1 , Bottleneck_val_SKU2 , Bottleneck_val_SKU3, Bottleneck_val_SKU4

# %% [markdown]
# ### 컬럼명 맞추기

# %%
# =========================
# 컬럼명 정규화: 언더스코어 여러 개 → 1개로 통일
# =========================
df.columns = df.columns.str.replace(r"__+", "_", regex=True)

# 확인
for sku in ["SKU1","SKU2","SKU3","SKU4"]:
    related_cols = [c for c in df.columns if f"Cell" in c and sku in c]
    print(sku, related_cols)
# Out:
# SKU1 ['c_Cell1_SKU1']
# SKU2 ['c_Cell1_SKU2', 'c_Cell2_SKU2', 'c_Cell3_SKU2']
# SKU3 ['c_Cell3_SKU3', 'c_Cell4_SKU3']
# SKU4 ['c_Cell1_SKU4', 'c_Cell2_SKU4', 'c_Cell4_SKU4']

# %% [markdown]
# ### 조립셀 Queue 값 -> SKU별로 분배
# - 각 Cell Queue 전체량을 SKU별 담당 비율에 따라 나눠서, SKU별 Cell Queue를 생성 -> SKU별로 여러 Cell에서 받은 몫을 합쳐 최종 SKU Cell Queue를 계산
# - 각 행에 대해 동적으로 SKU별 분배 수행

# %%
for sku in ["SKU1","SKU2","SKU3","SKU4"]:
    related_cols = [c for c in df.columns if f"_{sku}" in c and "c_Cell" in c]
    print(sku, related_cols)
# Out:
# SKU1 ['c_Cell1_SKU1']
# SKU2 ['c_Cell1_SKU2', 'c_Cell2_SKU2', 'c_Cell3_SKU2']
# SKU3 ['c_Cell3_SKU3', 'c_Cell4_SKU3']
# SKU4 ['c_Cell1_SKU4', 'c_Cell2_SKU4', 'c_Cell4_SKU4']

# %%
# ================================
# 2. SKU 경로 정의
# ================================
sku_paths = {
    "SKU1": {"blanking": "Blanking_SKU1_Queue","press": "Press1_Queue"},
    "SKU2": {"blanking": "Blanking_SKU2_Queue","press": "Press2_Queue"},
    "SKU3": {"blanking": "Blanking_SKU3_Queue","press": "Press3_Queue"},
    "SKU4": {"blanking": "Blanking_SKU4_Queue","press": "Press4_Queue"},
}

# ================================
# 3. Cell → SKU 비율 기반 분배
# ================================
sku_cell_vals = {sku: pd.Series(0, index=df.index) for sku in sku_paths}

for cell_num in range(1, 5):  # Cell1 ~ Cell4
    cell_col = f"Cell{cell_num}_Queue"
    
    if cell_col not in df.columns:
        continue
    
    # 해당 Cell Queue 값
    cell_vals = df[cell_col]
    
    for sku in sku_paths.keys():
        ratio_col = f"c_Cell{cell_num}_{sku}"
        if ratio_col in df.columns:
            # SKU별 Cell Queue = Cell Queue × 비율
            sku_cell_vals[sku] += cell_vals * df[ratio_col]

# ================================
# 4. 결과 DataFrame 구성 (컬럼명 변경)
# ================================
sku_cell_df = pd.DataFrame({
    f"Cell_{sku}_Queue": vals for sku, vals in sku_cell_vals.items()
})

print("=== SKU별로 분배된 Cell Queue (앞부분 10행) ===")
print(sku_cell_df.head(10))

# 원래 df에 붙이고 싶다면:
df = pd.concat([df, sku_cell_df], axis=1)
# Out:
# === SKU별로 분배된 Cell Queue (앞부분 10행) ===
#    Cell_SKU1_Queue  Cell_SKU2_Queue  Cell_SKU3_Queue  Cell_SKU4_Queue
# 0     1.370939e+06     1.192535e+06     1.247366e+06     8.856453e+05
# 1     2.451033e+06     1.958747e+06     9.126624e+05     1.182048e+06
# 2     5.568672e+06     3.817909e+06     9.283182e+05     1.242360e+06
# 3     1.647598e+06     1.114051e+06     1.090078e+06     1.048065e+06
# 4     1.553549e+06     1.232362e+06     1.476219e+06     1.102118e+06
# 5     2.101007e+06     1.931448e+06     1.167199e+06     1.028449e+06
# 6     1.851074e+06     1.886183e+06     6.287604e+05     8.966812e+05
# 7     2.972045e+06     2.248654e+06     1.170633e+06     1.487739e+06
# 8     5.720726e+06     4.591313e+06     9.949638e+05     1.545606e+06
# 9     5.471222e+06     3.388148e+06     7.908985e+05     1.160693e+06

# %%
# ================================
# 7. SKU별 병목 공정 예측
# ================================
sku_paths = {
    "SKU1": {"blanking": "Blanking_SKU1_Queue","press": "Press1_Queue", "cell": "Cell_SKU1_Queue"},
    "SKU2": {"blanking": "Blanking_SKU2_Queue","press": "Press2_Queue", "cell": "Cell_SKU2_Queue"},
    "SKU3": {"blanking": "Blanking_SKU3_Queue","press": "Press3_Queue", "cell": "Cell_SKU3_Queue"},
    "SKU4": {"blanking": "Blanking_SKU4_Queue","press": "Press4_Queue", "cell": "Cell_SKU4_Queue"},
}

for sku, paths in sku_paths.items():
    # 각 SKU별 병목 후보 Stage 값 모으기
    stage_df = df[[paths["blanking"], paths["press"], paths["cell"]]].copy()
    stage_df.columns = ["Blanking", "Press", "Cell"]  # 축 이름 단순화
    
    # 각 시점별 최대값 컬럼명 → 병목 공정
    df[f"Bottleneck_actual_{sku}"] = stage_df.idxmax(axis=1)

    # 각 시점별 병목 수치 (최대값)
    df[f"Bottleneck_val_{sku}"] = stage_df.max(axis=1)

# ================================
# 8. 결과 확인
# ================================
print(df[[c for c in df.columns if c.startswith("Bottleneck_actual_")]].head())
print(df[[c for c in df.columns if c.startswith("Bottleneck_val_")]].head())
# Out:
#   Bottleneck_actual_Blanking Bottleneck_actual_Press Bottleneck_actual_Cell  \
# 0        Blanking_SKU2_Queue            Press2_Queue            Cell1_Queue
# 1        Blanking_SKU2_Queue            Press1_Queue            Cell1_Queue
# 2        Blanking_SKU1_Queue            Press2_Queue            Cell1_Queue
# 3        Blanking_SKU4_Queue            Press1_Queue            Cell1_Queue
# 4        Blanking_SKU4_Queue            Press1_Queue            Cell1_Queue
#
#   Bottleneck_actual_SKU1 Bottleneck_actual_SKU2 Bottleneck_actual_SKU3  \
# 0                   Cell                   Cell                   Cell
# 1                   Cell                   Cell                   Cell
# 2                   Cell                   Cell                   Cell
# 3                   Cell                   Cell                   Cell
# 4                   Cell                   Cell                   Cell
#
#   Bottleneck_actual_SKU4
# 0                   Cell
# 1                   Cell
# 2                   Cell
# 3                   Cell
# 4                   Cell
#    Bottleneck_val_Blanking  Bottleneck_val_Press  Bottleneck_val_Cell  \
# 0                 0.056373             65.273786            98.155568
# 1                 0.052934             74.772823           162.632374
# 2                 0.052210             72.901066           335.401556
# 3                 0.052362             65.091192           112.173074
# 4                 0.057210             65.075312           107.982827
#
#    Bottleneck_val_SKU1  Bottleneck_val_SKU2  Bottleneck_val_SKU3  \
# 0         1.370939e+06         1.192535e+06         1.247366e+06
# 1         2.451033e+06         1.958747e+06         9.126624e+05
# 2         5.568672e+06         3.817909e+06         9.283182e+05
# 3         1.647598e+06         1.114051e+06         1.090078e+06
# 4         1.553549e+06         1.232362e+06         1.476219e+06
#
#    Bottleneck_val_SKU4
# 0         8.856453e+05
# 1         1.182048e+06
# 2         1.242360e+06
# 3         1.048065e+06
# 4         1.102118e+06

# %% [markdown]
# # 랜덤 분할 - Train 70 : Val 15 : Test 15

# %%
# from sklearn.model_selection import train_test_split

# train_val_df, test_df = train_test_split(df, test_size=0.15, random_state=42, shuffle=True)
# train_df, val_df = train_test_split(train_val_df, test_size=0.1765, random_state=42, shuffle=True)
# # 0.1765 ≈ 15% / 85%

# print(f"Train: {train_df.shape}, Val: {val_df.shape}, Test: {test_df.shape}")

# %%
# # 저장 경로 지정 (원하는 폴더로 바꾸세요)
# train_path = "./bottleneck_train.csv"
# val_path   = "./bottleneck_val.csv"
# test_path  = "./bottleneck_test.csv"

# # CSV 저장 (인덱스 제외)
# train_df.to_csv(train_path, index=False, encoding="utf-8-sig")
# val_df.to_csv(val_path, index=False, encoding="utf-8-sig")
# test_df.to_csv(test_path, index=False, encoding="utf-8-sig")

# print("✅ CSV 저장 완료")
# print(f"Train → {train_path} ({train_df.shape})")
# print(f"Val   → {val_path} ({val_df.shape})")
# print(f"Test  → {test_path} ({test_df.shape})")

# %%
import pandas as pd

# 경로 지정
train_path = "./bottleneck_train.csv"
val_path   = "./bottleneck_val.csv"
test_path  = "./bottleneck_test.csv"

# 불러오기
train_df = pd.read_csv(train_path)
val_df   = pd.read_csv(val_path)
test_df  = pd.read_csv(test_path)

# 하나로 합치고 싶으면
df = pd.concat([train_df, val_df, test_df], axis=0).reset_index(drop=True)

print("✅ 불러오기 완료")
print("Train:", train_df.shape, "Val:", val_df.shape, "Test:", test_df.shape)
print("전체 df:", df.shape)
# Out:
# ✅ 불러오기 완료
# Train: (92867, 76) Val: (19905, 76) Test: (19901, 76)
# 전체 df: (132673, 76)

# %% [markdown]
# # 독립변수 분리
# - 전체 기준 병목 예측
#     - 분류 : Bottleneck_actual
#     - 회귀 : Bottleneck_actual_val
# - 공정 단계 기준 병목 예측
#     - 분류 : Bottleneck_actual_Blanking , Bottleneck_actual_Press , Bottleneck_actual_Cell
#     - 회귀 : Bottleneck_val_Blanking , Bottleneck_val_Press , Bottleneck_val_Cell
# - 제품군(SKU) 기준 병목 예측
#     - 분류 : Bottleneck_actual_SKU1 , Bottleneck_actual_SKU2 , Bottleneck_actual_SKU3 , Bottleneck_actual_SKU4
#     - 회귀 : Bottleneck_val_SKU1 , Bottleneck_val_SKU2 , Bottleneck_val_SKU3, Bottleneck_val_SKU4

# %%
# 타깃 후보 컬럼 전부 정리
target_cols = [
    # 전체 기준
    "Bottleneck_actual", "Bottleneck_val",
    # 공정 단계 기준
    "Bottleneck_actual_Blanking", "Bottleneck_actual_Press", "Bottleneck_actual_Cell",
    "Bottleneck_val_Blanking", "Bottleneck_val_Press", "Bottleneck_val_Cell",
    # SKU 기준
    "Bottleneck_actual_SKU1", "Bottleneck_actual_SKU2", "Bottleneck_actual_SKU3", "Bottleneck_actual_SKU4",
    "Bottleneck_val_SKU1", "Bottleneck_val_SKU2", "Bottleneck_val_SKU3", "Bottleneck_val_SKU4"
]

# 독립변수(X)는 이 타깃 후보들을 제외한 것들만
X_train = train_df.drop(columns=[c for c in target_cols if c in train_df.columns])
X_val   = val_df.drop(columns=[c for c in target_cols if c in val_df.columns])
X_test  = test_df.drop(columns=[c for c in target_cols if c in test_df.columns])

print("✅ 독립변수 컬럼 수:", X_train.shape[1])
print("예시 컬럼:", X_train.columns[:10].tolist())
# Out:
# ✅ 독립변수 컬럼 수: 60
# 예시 컬럼: ['Blanking_Util', 'Blanking_SKU1_Queue', 'Blanking_SKU2_Queue', 'Blanking_SKU3_Queue', 'Blanking_SKU4_Queue', 'Press1_Util', 'Press2_Util', 'Press3_Util', 'Press4_Util', 'Press1_Queue']

# %% [markdown]
# # 전체 기준 병목 예측 모델링
# - 분류 : Bottleneck_actual
# - 회귀 : Bottleneck_actual_val

# %% [markdown]
# ### 전체 - 분류

# %% [markdown]
# ### 전체 - 회귀

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("✅ Using device:", device)

# ----- Torch Dataset -----
class NumpyDataset(torch.utils.data.Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.float32).view(-1, 1)
    def __len__(self): return len(self.X)
    def __getitem__(self, idx): return self.X[idx], self.y[idx]

# ----- 모델 정의 -----
class TorchMLPRegressor(nn.Module):
    def __init__(self, input_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(256, 128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 1)
        )
    def forward(self, x):
        return self.net(x)

# ----- 학습 함수 -----
def train_torch_mlp_reg(X_train, y_train, X_val, y_val,
                        epochs=100, lr=1e-3, batch_size=256, patience=10):
    train_loader = torch.utils.data.DataLoader(NumpyDataset(X_train, y_train), batch_size=batch_size, shuffle=True)
    val_loader   = torch.utils.data.DataLoader(NumpyDataset(X_val, y_val), batch_size=batch_size, shuffle=False)

    model = TorchMLPRegressor(X_train.shape[1]).to(device)
    criterion = nn.MSELoss()
    optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=1e-4)

    best_val_loss = np.inf
    patience_cnt = 0

    for epoch in range(1, epochs+1):
        # ---- Train ----
        model.train()
        train_loss = 0
        for xb, yb in train_loader:
            xb, yb = xb.to(device), yb.to(device)
            optimizer.zero_grad()
            out = model(xb)
            loss = criterion(out, yb)
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * len(xb)
        train_loss /= len(train_loader.dataset)

        # ---- Validation ----
        model.eval()
        with torch.no_grad():
            val_loss = 0
            for xb, yb in val_loader:
                xb, yb = xb.to(device), yb.to(device)
                out = model(xb)
                loss = criterion(out, yb)
                val_loss += loss.item() * len(xb)
            val_loss /= len(val_loader.dataset)

        print(f"[Epoch {epoch}] Train={train_loss:.4f}, Val={val_loss:.4f}")

        # EarlyStopping
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            patience_cnt = 0
            best_state = model.state_dict()
        else:
            patience_cnt += 1
            if patience_cnt >= patience:
                print("⏹ Early stopping triggered")
                break

    model.load_state_dict(best_state)
    return model

# ----- 데이터 준비 -----
y_train_reg = train_df["Bottleneck_val"].values
y_val_reg   = val_df["Bottleneck_val"].values
y_test_reg  = test_df["Bottleneck_val"].values

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled   = scaler.transform(X_val)
X_test_scaled  = scaler.transform(X_test)

# ----- 학습 -----
torch_mlp_reg = train_torch_mlp_reg(X_train_scaled, y_train_reg, X_val_scaled, y_val_reg,
                                    epochs=100, lr=1e-3, batch_size=256)

# ----- 테스트 평가 -----
torch_mlp_reg.eval()
with torch.no_grad():
    X_test_t = torch.tensor(X_test_scaled, dtype=torch.float32).to(device)
    preds = torch_mlp_reg(X_test_t).cpu().numpy().ravel()

mae = mean_absolute_error(y_test_reg, preds)
rmse = np.sqrt(mean_squared_error(y_test_reg, preds))
r2 = r2_score(y_test_reg, preds)

print(f"✅ TorchMLP Only | MAE={mae:.3f} | RMSE={rmse:.3f} | R2={r2:.3f}")
# Out:
# ✅ Using device: cuda
# [Epoch 1] Train=14353.3762, Val=171.7019
# [Epoch 2] Train=576.7136, Val=91.5669
# [Epoch 3] Train=518.5813, Val=49.4835
# [Epoch 4] Train=495.5786, Val=64.9350
# [Epoch 5] Train=476.0749, Val=58.7692
# [Epoch 6] Train=449.1229, Val=28.4604
# [Epoch 7] Train=459.4415, Val=62.1471
# [Epoch 8] Train=441.0202, Val=75.4217
# [Epoch 9] Train=432.8738, Val=91.5688
# [Epoch 10] Train=421.2386, Val=64.2286
# [Epoch 11] Train=424.2523, Val=38.6657
# [Epoch 12] Train=411.4498, Val=41.5911
# [Epoch 13] Train=402.1090, Val=44.2295
# [Epoch 14] Train=399.4622, Val=47.2210
# [Epoch 15] Train=390.5203, Val=71.4639
# [Epoch 16] Train=382.3200, Val=36.6554
# ⏹ Early stopping triggered
# ✅ TorchMLP Only | MAE=5.127 | RMSE=6.059 | R2=0.995

# %%
print(f"✅ TorchMLP Only | MAE={mae} | RMSE={rmse} | R2={r2}")
# Out:
# ✅ TorchMLP Only | MAE=5.1265395361583295 | RMSE=6.059305745598206 | R2=0.9948559857865491

# %% [markdown]
# # 공정 단계 기준 병목 예측 모델링
# - 분류 : Bottleneck_actual_Blanking , Bottleneck_actual_Press , Bottleneck_actual_Cell
# - 회귀 : Bottleneck_val_Blanking , Bottleneck_val_Press , Bottleneck_val_Cell

# %% [markdown]
# ### 공정단계 - 분류

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, f1_score, balanced_accuracy_score

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("✅ Using device:", device)

# ----- Torch Dataset -----
class NumpyDataset(torch.utils.data.Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.long)
    def __len__(self): return len(self.X)
    def __getitem__(self, idx): return self.X[idx], self.y[idx]

# ----- 모델 정의 -----
class TorchMLPClassifier(nn.Module):
    def __init__(self, input_dim, num_classes):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(256, 128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, num_classes)
        )
    def forward(self, x):
        return self.net(x)

# ----- 학습 함수 -----
def train_mlp_cls(X_train, y_train, X_val, y_val, num_classes,
                  epochs=100, lr=1e-3, batch_size=256, patience=10):
    train_loader = torch.utils.data.DataLoader(NumpyDataset(X_train, y_train), batch_size=batch_size, shuffle=True)
    val_loader   = torch.utils.data.DataLoader(NumpyDataset(X_val, y_val), batch_size=batch_size, shuffle=False)

    model = TorchMLPClassifier(X_train.shape[1], num_classes).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=1e-4)

    best_val_loss = np.inf
    patience_cnt = 0

    for epoch in range(1, epochs+1):
        # ---- Train ----
        model.train()
        train_loss = 0
        for xb, yb in train_loader:
            xb, yb = xb.to(device), yb.to(device)
            optimizer.zero_grad()
            out = model(xb)
            loss = criterion(out, yb)
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * len(xb)
        train_loss /= len(train_loader.dataset)

        # ---- Validation ----
        model.eval()
        with torch.no_grad():
            val_loss = 0
            for xb, yb in val_loader:
                xb, yb = xb.to(device), yb.to(device)
                out = model(xb)
                loss = criterion(out, yb)
                val_loss += loss.item() * len(xb)
            val_loss /= len(val_loader.dataset)

        print(f"[Epoch {epoch}] Train={train_loss:.4f}, Val={val_loss:.4f}")

        # EarlyStopping
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            patience_cnt = 0
            best_state = model.state_dict()
        else:
            patience_cnt += 1
            if patience_cnt >= patience:
                print("⏹ Early stopping triggered")
                break

    model.load_state_dict(best_state)
    return model

# ----- 실행 (공정 단계별 분류) -----
stage_targets_cls = [
    "Bottleneck_actual_Blanking",
    "Bottleneck_actual_Press",
    "Bottleneck_actual_Cell"
]

results_stage_cls = []

for target in stage_targets_cls:
    print(f"\n=== Classification for {target} ===")

    # ----- 라벨 인코딩 -----
    le = LabelEncoder()
    y_train = le.fit_transform(train_df[target])
    y_val   = le.transform(val_df[target])
    y_test  = le.transform(test_df[target])

    # ----- 스케일링 -----
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_val_scaled   = scaler.transform(X_val)
    X_test_scaled  = scaler.transform(X_test)

    # ----- 학습 -----
    torch_mlp = train_mlp_cls(
        X_train_scaled, y_train, X_val_scaled, y_val,
        num_classes=len(np.unique(y_train)), epochs=100
    )

    # ----- 테스트 -----
    torch_mlp.eval()
    with torch.no_grad():
        X_test_t = torch.tensor(X_test_scaled, dtype=torch.float32).to(device)
        logits = torch_mlp(X_test_t)
        y_pred = torch.argmax(logits, axis=1).cpu().numpy()

    acc = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred, average="macro")
    bal_acc = balanced_accuracy_score(y_test, y_pred)
    print(f"✅ TorchMLP Only | Acc={acc:.3f} | F1={f1:.3f} | BalAcc={bal_acc:.3f}")
    print(f"✅ TorchMLP Only | Acc={acc} | F1={f1} | BalAcc={bal_acc}")

    results_stage_cls.append({"target": target, "Acc": acc, "F1": f1, "BalAcc": bal_acc})

# ----- 성능 저장 -----
results_stage_cls_df = pd.DataFrame(results_stage_cls)
results_stage_cls_df.to_csv("stage_classification_results.csv", index=False, encoding="utf-8-sig")
print("✅ Stage Classification results saved to stage_classification_results.csv")
# Out:
# ✅ Using device: cuda
#
# === Classification for Bottleneck_actual_Blanking ===
# [Epoch 1] Train=0.3374, Val=0.1075
# [Epoch 2] Train=0.1805, Val=0.0910
# [Epoch 3] Train=0.1559, Val=0.0914
# [Epoch 4] Train=0.1449, Val=0.0812
# [Epoch 5] Train=0.1408, Val=0.0734
# [Epoch 6] Train=0.1383, Val=0.0776
# [Epoch 7] Train=0.1316, Val=0.0699
# [Epoch 8] Train=0.1331, Val=0.0705
# [Epoch 9] Train=0.1262, Val=0.0672
# [Epoch 10] Train=0.1269, Val=0.0707
# [Epoch 11] Train=0.1273, Val=0.0707
# [Epoch 12] Train=0.1232, Val=0.0662
# [Epoch 13] Train=0.1271, Val=0.0693
# [Epoch 14] Train=0.1257, Val=0.0670
# [Epoch 15] Train=0.1172, Val=0.0696
# [Epoch 16] Train=0.1195, Val=0.0679
# [Epoch 17] Train=0.1219, Val=0.0661
# [Epoch 18] Train=0.1210, Val=0.0630
# [Epoch 19] Train=0.1186, Val=0.0665
# [Epoch 20] Train=0.1182, Val=0.0673
# [Epoch 21] Train=0.1194, Val=0.0661
# [Epoch 22] Train=0.1170, Val=0.0674
# [Epoch 23] Train=0.1196, Val=0.0630
# [Epoch 24] Train=0.1153, Val=0.0640
# [Epoch 25] Train=0.1140, Val=0.0647
# [Epoch 26] Train=0.1182, Val=0.0670
# [Epoch 27] Train=0.1179, Val=0.0675
# [Epoch 28] Train=0.1140, Val=0.0633
# ⏹ Early stopping triggered
# ✅ TorchMLP Only | Acc=0.985 | F1=0.985 | BalAcc=0.985
# ✅ TorchMLP Only | Acc=0.9846238882468218 | F1=0.9846323667373398 | BalAcc=0.9846408646721387
#
# === Classification for Bottleneck_actual_Press ===
# [Epoch 1] Train=0.2785, Val=0.1117
# [Epoch 2] Train=0.1596, Val=0.0861
# [Epoch 3] Train=0.1402, Val=0.0766
# [Epoch 4] Train=0.1278, Val=0.0718
# [Epoch 5] Train=0.1197, Val=0.0650
# [Epoch 6] Train=0.1166, Val=0.0627
# [Epoch 7] Train=0.1173, Val=0.0630
# [Epoch 8] Train=0.1096, Val=0.0684
# [Epoch 9] Train=0.1152, Val=0.0603
# [Epoch 10] Train=0.1050, Val=0.0589
# [Epoch 11] Train=0.1058, Val=0.0603
# [Epoch 12] Train=0.1065, Val=0.0542
# [Epoch 13] Train=0.1031, Val=0.0546
# [Epoch 14] Train=0.1036, Val=0.0555
# [Epoch 15] Train=0.1011, Val=0.0575
# [Epoch 16] Train=0.1008, Val=0.0544
# [Epoch 17] Train=0.0985, Val=0.0516
# [Epoch 18] Train=0.0993, Val=0.0592
# [Epoch 19] Train=0.0980, Val=0.0514
# [Epoch 20] Train=0.0982, Val=0.0558
# [Epoch 21] Train=0.0961, Val=0.0504
# [Epoch 22] Train=0.0920, Val=0.0510
# [Epoch 23] Train=0.0945, Val=0.0511
# [Epoch 24] Train=0.0950, Val=0.0533
# [Epoch 25] Train=0.0917, Val=0.0606
# [Epoch 26] Train=0.0973, Val=0.0565
# [Epoch 27] Train=0.0955, Val=0.0545
# [Epoch 28] Train=0.0951, Val=0.0565
# [Epoch 29] Train=0.0907, Val=0.0541
# [Epoch 30] Train=0.0864, Val=0.0471
# [Epoch 31] Train=0.0904, Val=0.0504
# [Epoch 32] Train=0.0895, Val=0.0542
# [Epoch 33] Train=0.0911, Val=0.0552
# [Epoch 34] Train=0.0898, Val=0.0515
# [Epoch 35] Train=0.0868, Val=0.0480
# [Epoch 36] Train=0.0910, Val=0.0510
# [Epoch 37] Train=0.0927, Val=0.0551
# [Epoch 38] Train=0.0918, Val=0.0537
# [Epoch 39] Train=0.0908, Val=0.0522
# [Epoch 40] Train=0.0893, Val=0.0504
# ⏹ Early stopping triggered
# ✅ TorchMLP Only | Acc=0.984 | F1=0.976 | BalAcc=0.967
# ✅ TorchMLP Only | Acc=0.9836691623536505 | F1=0.9758991341949961 | BalAcc=0.9671868580019901
#
# === Classification for Bottleneck_actual_Cell ===
# [Epoch 1] Train=0.0903, Val=0.0402
# [Epoch 2] Train=0.0468, Val=0.0260
# [Epoch 3] Train=0.0412, Val=0.0259
# [Epoch 4] Train=0.0381, Val=0.0316
# [Epoch 5] Train=0.0368, Val=0.0223
# [Epoch 6] Train=0.0347, Val=0.0232
# [Epoch 7] Train=0.0331, Val=0.0250
# [Epoch 8] Train=0.0310, Val=0.0253
# [Epoch 9] Train=0.0307, Val=0.0198
# [Epoch 10] Train=0.0310, Val=0.0219
# [Epoch 11] Train=0.0285, Val=0.0188
# [Epoch 12] Train=0.0294, Val=0.0192
# [Epoch 13] Train=0.0279, Val=0.0178
# [Epoch 14] Train=0.0268, Val=0.0160
# [Epoch 15] Train=0.0265, Val=0.0169
# [Epoch 16] Train=0.0266, Val=0.0163
# [Epoch 17] Train=0.0256, Val=0.0187
# [Epoch 18] Train=0.0262, Val=0.0161
# [Epoch 19] Train=0.0243, Val=0.0146
# [Epoch 20] Train=0.0248, Val=0.0167
# [Epoch 21] Train=0.0248, Val=0.0165
# [Epoch 22] Train=0.0246, Val=0.0167
# [Epoch 23] Train=0.0253, Val=0.0183
# [Epoch 24] Train=0.0233, Val=0.0162
# [Epoch 25] Train=0.0230, Val=0.0161
# [Epoch 26] Train=0.0224, Val=0.0149
# [Epoch 27] Train=0.0223, Val=0.0162
# [Epoch 28] Train=0.0231, Val=0.0172
# [Epoch 29] Train=0.0235, Val=0.0190
# ⏹ Early stopping triggered
# ✅ TorchMLP Only | Acc=0.992 | F1=0.899 | BalAcc=0.862
# ✅ TorchMLP Only | Acc=0.9920104517360937 | F1=0.8987184823977952 | BalAcc=0.861858425297869
# ✅ Stage Classification results saved to stage_classification_results.csv

# %% [markdown]
# ### 공정단계 - 회귀

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("✅ Using device:", device)

# ----- Torch Dataset -----
class NumpyDataset(torch.utils.data.Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.float32).view(-1, 1)
    def __len__(self): return len(self.X)
    def __getitem__(self, idx): return self.X[idx], self.y[idx]

# ----- 모델 정의 -----
class TorchMLPRegressor(nn.Module):
    def __init__(self, input_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(256, 128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 1)
        )
    def forward(self, x):
        return self.net(x)

# ----- 학습 함수 -----
def train_torch_mlp_reg(X_train, y_train, X_val, y_val,
                        epochs=100, lr=1e-3, batch_size=256, patience=10):
    train_loader = torch.utils.data.DataLoader(NumpyDataset(X_train, y_train), batch_size=batch_size, shuffle=True)
    val_loader   = torch.utils.data.DataLoader(NumpyDataset(X_val, y_val), batch_size=batch_size, shuffle=False)

    model = TorchMLPRegressor(X_train.shape[1]).to(device)
    criterion = nn.MSELoss()
    optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=1e-4)

    best_val_loss = np.inf
    patience_cnt = 0

    for epoch in range(1, epochs+1):
        # ---- Train ----
        model.train()
        train_loss = 0
        for xb, yb in train_loader:
            xb, yb = xb.to(device), yb.to(device)
            optimizer.zero_grad()
            out = model(xb)
            loss = criterion(out, yb)
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * len(xb)
        train_loss /= len(train_loader.dataset)

        # ---- Validation ----
        model.eval()
        with torch.no_grad():
            val_loss = 0
            for xb, yb in val_loader:
                xb, yb = xb.to(device), yb.to(device)
                out = model(xb)
                loss = criterion(out, yb)
                val_loss += loss.item() * len(xb)
            val_loss /= len(val_loader.dataset)

        print(f"[Epoch {epoch}] Train={train_loss:.4f}, Val={val_loss:.4f}")

        # EarlyStopping
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            patience_cnt = 0
            best_state = model.state_dict()
        else:
            patience_cnt += 1
            if patience_cnt >= patience:
                print("⏹ Early stopping triggered")
                break

    model.load_state_dict(best_state)
    return model

# ----- 실행 (공정 단계별 회귀) -----
stage_targets_reg = [
    "Bottleneck_val_Blanking",
    "Bottleneck_val_Press",
    "Bottleneck_val_Cell"
]

results_stage_reg = []

for target in stage_targets_reg:
    print(f"\n=== Regression for {target} ===")

    y_train = train_df[target].values
    y_val   = val_df[target].values
    y_test  = test_df[target].values

    # ----- 스케일링 -----
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_val_scaled   = scaler.transform(X_val)
    X_test_scaled  = scaler.transform(X_test)

    # ----- 학습 -----
    torch_mlp_reg = train_torch_mlp_reg(
        X_train_scaled, y_train,
        X_val_scaled, y_val,
        epochs=100, lr=1e-3, batch_size=256
    )

    # ----- 테스트 -----
    torch_mlp_reg.eval()
    with torch.no_grad():
        X_test_t = torch.tensor(X_test_scaled, dtype=torch.float32).to(device)
        preds = torch_mlp_reg(X_test_t).cpu().numpy().ravel()

    mae = mean_absolute_error(y_test, preds)
    rmse = np.sqrt(mean_squared_error(y_test, preds))
    r2 = r2_score(y_test, preds)
    print(f"✅ TorchMLP Only | Target={target} | MAE={mae:.3f} | RMSE={rmse:.3f} | R2={r2:.3f}")
    print(f"✅ TorchMLP Only | Target={target} | MAE={mae} | RMSE={rmse} | R2={r2}")

    results_stage_reg.append({"target": target, "MAE": mae, "RMSE": rmse, "R2": r2})

# ----- 성능 저장 -----
results_stage_reg_df = pd.DataFrame(results_stage_reg)
results_stage_reg_df.to_csv("stage_regression_results.csv", index=False, encoding="utf-8-sig")
print("✅ Stage Regression results saved to stage_regression_results.csv")
# Out:
# ✅ Using device: cuda
#
# === Regression for Bottleneck_val_Blanking ===
# [Epoch 1] Train=0.0020, Val=0.0001
# [Epoch 2] Train=0.0001, Val=0.0000
# [Epoch 3] Train=0.0000, Val=0.0000
# [Epoch 4] Train=0.0000, Val=0.0000
# [Epoch 5] Train=0.0000, Val=0.0000
# [Epoch 6] Train=0.0000, Val=0.0000
# [Epoch 7] Train=0.0000, Val=0.0000
# [Epoch 8] Train=0.0000, Val=0.0000
# [Epoch 9] Train=0.0000, Val=0.0000
# [Epoch 10] Train=0.0000, Val=0.0000
# [Epoch 11] Train=0.0000, Val=0.0000
# [Epoch 12] Train=0.0000, Val=0.0000
# [Epoch 13] Train=0.0000, Val=0.0000
# [Epoch 14] Train=0.0000, Val=0.0000
# [Epoch 15] Train=0.0000, Val=0.0000
# [Epoch 16] Train=0.0000, Val=0.0000
# [Epoch 17] Train=0.0000, Val=0.0000
# [Epoch 35] Train=10.4436, Val=1.1264
# [Epoch 36] Train=10.3308, Val=1.2346
# [Epoch 37] Train=10.0844, Val=2.4789
# [Epoch 38] Train=9.7949, Val=1.4310
# [Epoch 39] Train=9.4111, Val=5.0834
# [Epoch 40] Train=9.0183, Val=5.5716
# [Epoch 41] Train=8.7886, Val=0.8544
# [Epoch 42] Train=8.6694, Val=1.0851
# [Epoch 43] Train=8.3210, Val=1.0817
# [Epoch 44] Train=8.2218, Val=1.7280
# [Epoch 45] Train=8.1556, Val=1.2790
# [Epoch 46] Train=8.0603, Val=1.4132
# [Epoch 47] Train=7.9309, Val=0.8970
# [Epoch 48] Train=7.6602, Val=3.0204
# [Epoch 49] Train=7.8467, Val=7.8650
# [Epoch 50] Train=7.0863, Val=0.9770
# [Epoch 51] Train=7.4208, Val=1.6584
# ⏹ Early stopping triggered
# ✅ TorchMLP Only | Target=Bottleneck_val_Press | MAE=1.024 | RMSE=1.300 | R2=0.991
# ✅ TorchMLP Only | Target=Bottleneck_val_Press | MAE=1.0244279220328616 | RMSE=1.3003772731549612 | R2=0.991190688168204
#
# === Regression for Bottleneck_val_Cell ===
# [Epoch 1] Train=13393.8385, Val=140.4458
# [Epoch 2] Train=556.4348, Val=130.5429
# [Epoch 3] Train=495.9749, Val=93.9375
# [Epoch 4] Train=482.0952, Val=107.0710
# [Epoch 5] Train=462.2322, Val=71.8535
# [Epoch 6] Train=443.0233, Val=54.7712
# [Epoch 7] Train=430.4765, Val=51.2564
# [Epoch 8] Train=412.1167, Val=89.2637
# [Epoch 9] Train=415.7595, Val=64.9508
# [Epoch 10] Train=397.6198, Val=35.0321
# [Epoch 11] Train=406.8605, Val=79.8024
# [Epoch 12] Train=385.5761, Val=45.3477
# [Epoch 13] Train=373.7490, Val=31.8178
# [Epoch 14] Train=377.3133, Val=43.1216
# [Epoch 15] Train=367.6635, Val=42.3391
# [Epoch 16] Train=353.2956, Val=79.4026
# [Epoch 17] Train=353.9728, Val=29.5196
# [Epoch 18] Train=354.4398, Val=57.1015
# [Epoch 19] Train=338.0866, Val=79.6584
# [Epoch 20] Train=342.3289, Val=18.6111
# [Epoch 21] Train=333.7208, Val=18.6299
# [Epoch 22] Train=333.7359, Val=23.1365
# [Epoch 23] Train=338.2285, Val=35.5498
# [Epoch 24] Train=337.3428, Val=23.8151
# [Epoch 25] Train=318.9630, Val=98.1040
# [Epoch 26] Train=327.5779, Val=35.6347
# [Epoch 27] Train=315.0741, Val=32.7058
# [Epoch 28] Train=307.9008, Val=38.2354
# [Epoch 29] Train=314.7136, Val=34.5700
# [Epoch 30] Train=311.8914, Val=49.1507
# ⏹ Early stopping triggered
# ✅ TorchMLP Only | Target=Bottleneck_val_Cell | MAE=6.104 | RMSE=7.047 | R2=0.994
# ✅ TorchMLP Only | Target=Bottleneck_val_Cell | MAE=6.103826008309294 | RMSE=7.047093067863547 | R2=0.9942426554067374
# ✅ Stage Regression results saved to stage_regression_results.csv

# %% [markdown]
# # 제품군(SKU) 기준 병목 예측 모델링
# - 분류 : Bottleneck_actual_SKU1 , Bottleneck_actual_SKU2 , Bottleneck_actual_SKU3 , Bottleneck_actual_SKU4
# - 회귀 : Bottleneck_val_SKU1 , Bottleneck_val_SKU2 , Bottleneck_val_SKU3, Bottleneck_val_SKU4

# %% [markdown]
# ### 제품군(SKU) - 회귀

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("✅ Using device:", device)

# ----- Torch Dataset -----
class NumpyDataset(torch.utils.data.Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.float32).view(-1, 1)
    def __len__(self): return len(self.X)
    def __getitem__(self, idx): return self.X[idx], self.y[idx]

# ----- 모델 정의 -----
class TorchMLPRegressor(nn.Module):
    def __init__(self, input_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(256, 128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 1)
        )
    def forward(self, x):
        return self.net(x)

# ----- 학습 함수 -----
def train_torch_mlp_reg(X_train, y_train, X_val, y_val,
                        epochs=100, lr=1e-3, batch_size=256, patience=10):
    train_loader = torch.utils.data.DataLoader(NumpyDataset(X_train, y_train), batch_size=batch_size, shuffle=True)
    val_loader   = torch.utils.data.DataLoader(NumpyDataset(X_val, y_val), batch_size=batch_size, shuffle=False)

    model = TorchMLPRegressor(X_train.shape[1]).to(device)
    criterion = nn.MSELoss()
    optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=1e-4)

    best_val_loss = np.inf
    patience_cnt = 0

    for epoch in range(1, epochs+1):
        # ---- Train ----
        model.train()
        train_loss = 0
        for xb, yb in train_loader:
            xb, yb = xb.to(device), yb.to(device)
            optimizer.zero_grad()
            out = model(xb)
            loss = criterion(out, yb)
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * len(xb)
        train_loss /= len(train_loader.dataset)

        # ---- Validation ----
        model.eval()
        with torch.no_grad():
            val_loss = 0
            for xb, yb in val_loader:
                xb, yb = xb.to(device), yb.to(device)
                out = model(xb)
                loss = criterion(out, yb)
                val_loss += loss.item() * len(xb)
            val_loss /= len(val_loader.dataset)

        print(f"[Epoch {epoch}] Train={train_loss:.4f}, Val={val_loss:.4f}")

        # EarlyStopping
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            patience_cnt = 0
            best_state = model.state_dict()
        else:
            patience_cnt += 1
            if patience_cnt >= patience:
                print("⏹ Early stopping triggered")
                break

    model.load_state_dict(best_state)
    return model

# ----- 실행 (SKU별 회귀) -----
sku_targets_reg = [
    "Bottleneck_val_SKU1",
    "Bottleneck_val_SKU2",
    "Bottleneck_val_SKU3",
    "Bottleneck_val_SKU4"
]

results_sku_reg = []

for target in sku_targets_reg:
    print(f"\n=== Regression for {target} ===")

    y_train = train_df[target].values
    y_val   = val_df[target].values
    y_test  = test_df[target].values

    # ----- 스케일링 -----
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_val_scaled   = scaler.transform(X_val)
    X_test_scaled  = scaler.transform(X_test)

    # ----- 학습 -----
    torch_mlp_reg = train_torch_mlp_reg(
        X_train_scaled, y_train,
        X_val_scaled, y_val,
        epochs=100, lr=1e-3, batch_size=256
    )

    # ----- 테스트 -----
    torch_mlp_reg.eval()
    with torch.no_grad():
        X_test_t = torch.tensor(X_test_scaled, dtype=torch.float32).to(device)
        preds = torch_mlp_reg(X_test_t).cpu().numpy().ravel()

    mae = mean_absolute_error(y_test, preds)
    rmse = np.sqrt(mean_squared_error(y_test, preds))
    r2 = r2_score(y_test, preds)
    print(f"✅ TorchMLP Only | Target={target} | MAE={mae:.3f} | RMSE={rmse:.3f} | R2={r2:.3f}")
    print(f"✅ TorchMLP Only | Target={target} | MAE={mae} | RMSE={rmse} | R2={r2}")

    results_sku_reg.append({"target": target, "MAE": mae, "RMSE": rmse, "R2": r2})

# ----- 성능 저장 -----
results_sku_reg_df = pd.DataFrame(results_sku_reg)
results_sku_reg_df.to_csv("sku_regression_results.csv", index=False, encoding="utf-8-sig")
print("✅ SKU Regression results saved to sku_regression_results.csv")
# Out:
# ✅ Using device: cuda
#
# === Regression for Bottleneck_val_SKU1 ===
# [Epoch 1] Train=11455733241056.2461, Val=11471866382114.4805
# [Epoch 2] Train=11399544027895.9258, Val=11361135319009.2363
# [Epoch 3] Train=11216060730230.1133, Val=11099484850254.9160
# [Epoch 4] Train=10854798390675.7578, Val=10629395897295.0762
# [Epoch 5] Train=10287536961107.3555, Val=9897836807684.8613
# [Epoch 6] Train=9522570254571.3281, Val=9061668560786.9375

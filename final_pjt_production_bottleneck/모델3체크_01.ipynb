# %%
from pathlib import Path
import pandas as pd
import numpy as np

# 노트북이 위치한 루트를 기준으로 설정 (노트북이 루트에 있다는 전제)
ROOT = Path.cwd()

MODEL1_DIR = ROOT / "Model 1"
MODEL2_DIR = ROOT / "Model 2"
MODEL3_DIR = ROOT / "Model 3"

MAT_PATH   = ROOT / "3000Samplesv3.mat"  # 루트에 있다고 가정

# %% [markdown]
# ### 1) Model 3/Model_3.csv 읽기 (Pandas)

# %%
csv_path = MODEL3_DIR / "Model_3.csv"

# 인코딩 이슈가 있으면 encoding='cp949' 등 시도
df3 = pd.read_csv(csv_path)  # 또는 pd.read_csv(csv_path, encoding='utf-8')
print("Model_3.csv:", df3.shape)
print("columns:", df3.columns.tolist()[:30])
display(df3.head())
# Out:
# Model_3.csv: (605620, 78)
# columns: ['Time_Now', 'Blanking_Util', 'Blanking_SKU1_Queue', 'Blanking_SKU2_Queue', 'Blanking_SKU3_Queue', 'Blanking_SKU4_Queue', 'Press1_Util', 'Press2_Util', 'Press3_Util', 'Press4_Util', 'Press1_Queue', 'Press2_Queue', 'Press3_Queue', 'Press4_Queue', 'Cell1_Util', 'Cell2_Util', 'Cell3_Util', 'Cell4_Util', 'Cell1_Queue', 'Cell2_Queue', 'Cell3_Queue', 'Cell4_Queue', 'Warehouse1_Queue', 'Warehouse_2_Queue', 'Warehouse_3_Queue', 'Warehouse_4_Queue', 'c_Cycle1', 'c_Cycle2', 'c_Cycle3', 'c_Cycle4']
#    Time_Now  Blanking_Util  Blanking_SKU1_Queue  Blanking_SKU2_Queue  \
# 0        24       0.846367             0.045715             0.056373
# 1        24       0.851097             0.051937             0.052934
# 2        24       0.846115             0.052210             0.047499
# 3        24       0.841306             0.051769             0.035436
# 4        24       0.859599             0.045874             0.046802
#
# ...

# %%
df3.shape
# Out:
# (605620, 78)
